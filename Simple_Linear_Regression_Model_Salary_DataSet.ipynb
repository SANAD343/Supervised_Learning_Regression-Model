# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/sample_data/Salary_Data.csv")

# %%
df.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 60

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.shape
# Out:
# (30, 2)

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.nunique()
# Out:
# YearsExperience    28
# Salary             30
# dtype: int64

# %%
df["YearsExperience"].unique()
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.7,  3.9,  4. ,
#         4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,  7.9,  8.2,
#         8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
df["Salary"].unique()
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.isnull().any(axis=0)
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
df["YearsExperience"]
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
df["Salary"]
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
features=df["YearsExperience"].values #feature (x)(dependent)
print(features)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]

# %%
labels=df["Salary"].values #labels (y) (independent)
print(labels)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
df.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0

# %%
features.shape
# Out:
# (30,)

# %%
features.ndim
# Out:
# 1

# %%
features.size
# Out:
# 30

# %%
labels.shape
# Out:
# (30,)

# %%
labels.size
# Out:
# 30

# %%
#representing the labels and features values within the scatter plot

# %%
plt.scatter(features,labels)

# %%
#now implement the Linear Regression to find the best fit line

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
features=features.reshape(30,1)

# %%
features.ndim
# Out:
# 2

# %%
#now fit the Linear Regression Model

# %%
reg.fit(features,labels)
# Out:
# LinearRegression()

# %%
m=reg.coef_  #coefficient
m
# Out:
# array([9449.96232146])

# %%
c=reg.intercept_ #intercept
c
# Out:
# 25792.200198668696

# %%
x=3
y=m*x+c

# %%
y
# Out:
# array([54142.08716303])

# %%
reg.predict([[3]])
# Out:
# array([54142.08716303])

# %%
reg.predict([[3.2]])
# Out:
# array([56032.07962732])

# %%
#now print the best fit line

# %%
plt.scatter(features,reg.predict(features))

# %%
reg.predict(([[5.2]]))
# Out:
# array([74932.00427024])

# %%
#now train the model and find the score of the model (accuracy)

# %%
from sklearn.model_selection import train_test_split
features_train,features_test,labels_train,labels_test=train_test_split(features,labels,test_size=0.25)

# %%
features_train.ndim
# Out:
# 2

# %%
features_test.ndim
# Out:
# 2

# %%
labels_train.ndim
# Out:
# 1

# %%
labels_test.ndim
# Out:
# 1

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(features_train,labels_train)
# Out:
# LinearRegression()

# %%
reg.predict(features_test)
# Out:
# array([116361.74135117, 117295.47150157,  75277.61473337,  54735.55142448,
#         82747.45593661,  65940.31322933,  65006.58307892,  48199.44037164])

# %%
labels_test
# Out:
# array([116969., 112635.,  66029.,  56642.,  81363.,  57081.,  56957.,
#         39891.])

# %%
labels_train
# Out:
# array([ 60150.,  55794.,  91738., 101302.,  67938., 122391.,  61111.,
#         54445., 113812.,  43525.,  63218., 109431., 121872.,  83088.,
#         46205.,  64445.,  39343.,  98273.,  57189.,  37731.,  93940.,
#        105582.])

# %%
pred=reg.predict(features_test)

# %%
pred
# Out:
# array([116361.74135117, 117295.47150157,  75277.61473337,  54735.55142448,
#         82747.45593661,  65940.31322933,  65006.58307892,  48199.44037164])

# %%
pd.DataFrame(zip(pred,labels_test))
# Out:
#                0         1
# 0  116361.741351  116969.0
# 1  117295.471502  112635.0
# 2   75277.614733   66029.0
# 3   54735.551424   56642.0
# 4   82747.455937   81363.0
# 5   65940.313229   57081.0
# 6   65006.583079   56957.0
# 7   48199.440372   39891.0

# %%
#training Data Score (Accuracy)

# %%
reg.score(features_train,labels_train)
# Out:
# 0.9590995552307341

# %%
#testing Data Score (Accuracy)

# %%
reg.score(features_test,labels_test)
# Out:
# 0.9407739954625256

# %%
score=reg.predict([[10.4]])
print(score)
# Out:
# [124765.31270481]

# %%
#visulization

# %%
plt.figure(dpi=120)
plt.title("Salary Plotter")
plt.ylabel("Salary")
plt.xlabel("YearsExperiance")
plt.xticks(range(0,12))
plt.scatter(features_train,labels_train, color="blue",label="datapoints")
plt.plot(features_train,reg.predict(features_train),color="red",label="line")
plt.legend()

# %%
plt.figure(dpi=100)
plt.title("Salary Plotter")
plt.ylabel("Salary")
plt.xlabel("YearsExperiance")
plt.xticks(range(0,12))
plt.scatter(features_test,labels_test, color="green",label="datapoints")
plt.plot(features_test,reg.predict(features_test),color="red",label="line")
plt.legend()

# %%
plt.figure(dpi=120)
plt.title("Salary Plotter")
plt.ylabel("Salary")
plt.xlabel("YearsExperiance")
plt.xticks(range(0,12))
plt.scatter(features_train,labels_train, color="#2d6d7d",label="datapoints")
plt.plot(features_test,reg.predict(features_test),color="#9c8194",label="line")
plt.legend()

# %%
plt.figure(dpi=120)
plt.title("Salary Plotter")
plt.ylabel("Salary")
plt.xlabel("YearsExperiance")
plt.xticks(range(0,12))
plt.scatter(features_train,labels_train, color="#12414d",label="train")
plt.scatter(features_test,labels_test,color="yellow",label="test")
plt.plot(features_train,reg.predict(features_train),color="orange",label="trainline")
plt.plot(features_test,reg.predict(features_test),color="blue",label="testline")

plt.legend()

# %%
c1=features_test.ravel()
c2=labels_test.ravel()
c3=reg.predict(features_test).ravel()
c4=(labels_test-reg.predict(features_test)).ravel()
df2=pd.DataFrame({"YearsExperiance":c1,"ActualValue":c2,"PredictedValue":c3,"Differences":c4})

# %%
print(df2)
# Out:
#    YearsExperiance  ActualValue  PredictedValue  Differences
# 0              9.5     116969.0   116361.741351   607.258649
# 1              9.6     112635.0   117295.471502 -4660.471502
# 2              5.1      66029.0    75277.614733 -9248.614733
# 3              2.9      56642.0    54735.551424  1906.448576
# 4              5.9      81363.0    82747.455937 -1384.455937
# 5              4.1      57081.0    65940.313229 -8859.313229
# 6              4.0      56957.0    65006.583079 -8049.583079
# 7              2.2      39891.0    48199.440372 -8308.440372
